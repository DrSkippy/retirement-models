# %%
data_path = "../output/metrics"

# %%
import os
import pandas as pd
import string

# Directory containing your CSV files
data_dir = "../output/metrics/"

# Get list of all CSV files in the directory
files = [f for f in os.listdir(data_dir) if f.lower().endswith(".csv")]

dfs = [pd.read_csv(data_dir + fp) for fp in files]

merged_df = pd.concat(dfs)

print(merged_df.describe())
# Out:
# ['net_worth_d2e748da-74a7-11f0-be76-d45d6408926d.csv', 'net_worth_cd5598a4-74a7-11f0-be76-d45d6408926d.csv', 'net_worth_da03286e-74a7-11f0-be76-d45d6408926d.csv', 'net_worth_dc6b3e2a-74a7-11f0-be76-d45d6408926d.csv', 'net_worth_e1cc7d2a-74a7-11f0-be76-d45d6408926d.csv', 'net_worth_d794337a-74a7-11f0-be76-d45d6408926d.csv', 'net_worth_df18dfe2-74a7-11f0-be76-d45d6408926d.csv', 'net_worth_d06db99a-74a7-11f0-be76-d45d6408926d.csv', 'net_worth_d54142c0-74a7-11f0-be76-d45d6408926d.csv']
#             Period     net_worth
# count  3393.000000  3.393000e+03
# mean    188.000000  6.703159e+06
# std     108.846184  1.819852e+06
# min       0.000000  3.291747e+06
# 25%      94.000000  5.629321e+06
# 50%     188.000000  6.517564e+06
# 75%     282.000000  7.828029e+06
# max     376.000000  1.304561e+07

# %%
import matplotlib
from matplotlib import pylab as plt

# %%
merged_df.plot.scatter("Period", "net_worth", figsize=[12,6])
# Out:
# <Axes: xlabel='Period', ylabel='net_worth'>
